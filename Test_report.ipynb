# %%
import pandas as pd

# %%
from validators.new_ias_report_ai import read_report

# %%
df = read_report()
df
# Out:
#      Реестр №                          Основной календарь/раздел  \
# 0       70518  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 1       70508  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 2       55496  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 3       54214  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 4       55505  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# ..        ...                                                ...
# 686     90059  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 687     90060  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 688     90061  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 689     90062  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 690     89743  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
#
#                       Дополнительные календари/разделы  \
# 0    ЕКП г. Москвы на 2025 год / 5.3. Аккредитованн...
# 1    ЕКП г. Москвы на 2025 год / 5.3. Аккредитованн...
# ...
