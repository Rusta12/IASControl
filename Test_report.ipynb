# %%
import pandas as pd

# %%
from validators.new_ias_report_ai import read_report

# %%
df = read_report()
df
# Out:
#       Реестр №                          Основной календарь/раздел  \
# 0        66752  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 1        66751  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 2         3592  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 3        70518  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 4        70508  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# ...        ...                                                ...
# 1867     64078  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 1868     75474  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 1869     76555  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 1870     76926  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
# 1871     77047  ЕКП г. Москвы на 2025 год / 2.1. Подраздел «Сп...
#
#                        Дополнительные календари/разделы  \
# 0     ЕКП г. Москвы на 2025 год / 6.1. ГКУ «ЦСТиСК» ...
# 1     ЕКП г. Москвы на 2025 год / 6.1. ГКУ «ЦСТиСК» ...
# ...
