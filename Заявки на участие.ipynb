# %%
import pandas as pd
import numpy as np
import os
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
file_name = r"C:/DataIAS/Список спортмероприятий (участие).xlsx"
xls = pd.ExcelFile(file_name)
df = pd.read_excel(xls, 'Sheet1')

# %% [markdown]
# ias.search_party(df_list)

# %%
import new_ias_main_function as ias
ias.paty_approve(2024, df)
# Out:
# 0 из 71
# === 89012 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1 из 71
# === 89151 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 2 из 71
# === 89188 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 3 из 71
# === 89017 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 4 из 71
# === 89095 ===
# 2
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 5 из 71
# === 89126 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 6 из 71
# === 89127 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 7 из 71
# === 81829 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 8 из 71
# === 89019 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 9 из 71
# === 81911 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 10 из 71
# === 87521 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 11 из 71
# === 89256 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 12 из 71
# === 81787 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 13 из 71
# === 89321 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 14 из 71
# === 89098 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 15 из 71
# === 89310 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 16 из 71
# === 89322 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 17 из 71
# === 89324 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 18 из 71
# === 81039 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 19 из 71
# === 82032 ===
# 2
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 20 из 71
# === 89319 ===
# 2
# 0 (на согласование)
# 1 (проект)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 21 из 71
# === 81140 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 22 из 71
# === 87519 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 23 из 71
# === 61504 ===
# 8
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 24 из 71
# === 87902 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 25 из 71
# === 87895 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 26 из 71
# === 87893 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 27 из 71
# === 57999 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (на согласование)
# [7]  Это список согла!
# 7
# Элемент найден!
# Участие соглосованно
# 28 из 71
# === 89311 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 89311 Ошибка функции
# 29 из 71
# === 79369 ===
# 3
# 0 (на согласование)
# 1 (утверждена)
# 2 (на согласование)
# [0, 2]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 2
# 79369 Ошибка функции
# 30 из 71
# === 63849 ===
# 4
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# Элемент найден!
# Участие соглосованно
# 31 из 71
# === 83529 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 83529 Ошибка функции
# 32 из 71
# === 89073 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 33 из 71
# === 63933 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 34 из 71
# === 81057 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 35 из 71
# === 89298 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 36 из 71
# === 89309 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# Элемент найден!
# Участие соглосованно
# 37 из 71
# === 84280 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 84280 Ошибка функции
# 38 из 71
# === 62486 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 39 из 71
# === 89085 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 40 из 71
# === 89205 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 41 из 71
# === 57154 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 42 из 71
# === 81080 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 43 из 71
# === 89068 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 44 из 71
# === 89243 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 45 из 71
# === 89248 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 46 из 71
# === 89302 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 47 из 71
# === 89307 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 48 из 71
# === 81113 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 49 из 71
# === 88423 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 50 из 71
# === 88425 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 51 из 71
# === 89289 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 52 из 71
# === 89142 ===
# 4
# 0 (на согласование)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# [0, 2, 3]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 2
# 89142 Ошибка функции
# 53 из 71
# === 89212 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 54 из 71
# === 89211 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 55 из 71
# === 89254 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# Элемент найден!
# Участие соглосованно
# 56 из 71
# === 88392 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 57 из 71
# === 80516 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 58 из 71
# === 88654 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 59 из 71
# === 70676 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 60 из 71
# === 89091 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 61 из 71
# === 72412 ===
# 5
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 62 из 71
# === 69565 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# 4 (утверждена)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 63 из 71
# === 89061 ===
# 9
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 64 из 71
# === 89063 ===
# 6
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 65 из 71
# === 89064 ===
# 5
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 66 из 71
# === 62482 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (на согласование)
# 9 (утверждена)
# [8]  Это список согла!
# 8
# Элемент найден!
# Участие соглосованно
# 67 из 71
# === 88322 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 68 из 71
# === 77020 ===
# 3
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 69 из 71
# === 87221 ===
# 6
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (утверждена)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 70 из 71
# === 87224 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# 4 (на согласование)
# [3, 4]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 4
# Элемент найден!
# Участие соглосованно
# 71 из 71
# === 85303 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# [89311, 79369, 83529, 84280, 89142]

# %%
df = (df[df['Реестр №'] < 0])
df.to_excel(file_name, index=False)

# %%
text = """
57669, 6.3. ГБУ ДО «ФСО «Юность Москвы» ГБУ ДО «ФСО «Юность Москвы» (утверждена) с 03.02.2024 по 06.02.2024 обл. Орловская, г. Орёл спорт. м. спорт. ж.
\n
57669, 6.4. ГБУ ДО «МГФСО» ГБУ ДО «МГФСО» (утверждена) с 04.02.2024 по 06.02.2024 обл. Орловская, г. Орёл
\n
57669, 6.3. ГБУ ДО «ФСО «Юность Москвы» ГБУ ДО «ФСО «Юность Москвы» (на согласование) с 09.02.2024 по 12.02.2024 обл. Орловская, г. Орёл спорт. м. 6 спорт. ж. 2
"""

# %%
import re
values_in_brackets = re.findall(r'\((.*?)\)', text)
for idx, value in enumerate(values_in_brackets, 0):
    print(f"{idx} {value}")
    if value == 'на согласование':
        print(idx)
    else:
        pass
# Out:
# 0 утверждена
# 1 утверждена
# 2 на согласование
# 2

# %%
pattern = re.compile(r'\(утверждена\)|\(на согласование\)')

matches = re.findall(pattern, text)
for match in matches:
    print(match)
# Out:
# (утверждена)
# (утверждена)
# (на согласование)
