# %%
import pandas as pd
import numpy as np
import os
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
file_name = r"C:/DataIAS/Список спортмероприятий (участие).xlsx"
xls = pd.ExcelFile(file_name)
df = pd.read_excel(xls, 'Sheet1')

# %% [markdown]
# ias.search_party(df_list)

# %%
import new_ias_main_function as ias
ias.paty_approve(2025, df)
# Out:
# 0 из 653
# === 90172 ===
# 90172 Мероприятие не найдено
# 1 из 653
# === 91354 ===
# 91354 Мероприятие не найдено
# 2 из 653
# === 89530 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 3 из 653
# === 89682 ===
# 89682 Мероприятие не найдено
# 4 из 653
# === 90763 ===
# 90763 Мероприятие не найдено
# 5 из 653
# === 90994 ===
# 90994 Мероприятие не найдено
# 6 из 653
# === 39004 ===
# 39004 Мероприятие не найдено
# 7 из 653
# === 89674 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 8 из 653
# === 90784 ===
# 90784 Мероприятие не найдено
# 9 из 653
# === 90156 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 10 из 653
# === 91780 ===
# 91780 Мероприятие не найдено
# 11 из 653
# === 91446 ===
# 91446 Мероприятие не найдено
# 12 из 653
# === 89988 ===
# 89988 Мероприятие не найдено
# 13 из 653
# === 91387 ===
# 91387 Мероприятие не найдено
# 14 из 653
# === 66423 ===
# 66423 Мероприятие не найдено
# 15 из 653
# === 81838 ===
# 81838 Мероприятие не найдено
# 16 из 653
# === 89554 ===
# 89554 Мероприятие не найдено
# 17 из 653
# === 91013 ===
# 91013 Мероприятие не найдено
# 18 из 653
# === 91751 ===
# 91751 Мероприятие не найдено
# 19 из 653
# === 91007 ===
# 91007 Мероприятие не найдено
# 20 из 653
# === 90018 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 21 из 653
# === 91058 ===
# 91058 Мероприятие не найдено
# 22 из 653
# === 89560 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (утверждена)
# 5 (на согласование)
# [2, 3, 5]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 5
# 89560 Ошибка функции
# 23 из 653
# === 90330 ===
# 90330 Мероприятие не найдено
# 24 из 653
# === 81021 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# [2, 3, 4, 5]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 81021 Ошибка функции
# 25 из 653
# === 90141 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 26 из 653
# === 90267 ===
# 90267 Мероприятие не найдено
# 27 из 653
# === 89986 ===
# 89986 Мероприятие не найдено
# 28 из 653
# === 91268 ===
# 91268 Мероприятие не найдено
# 29 из 653
# === 63209 ===
# 10
# 0 (утверждена)
# 1 (проект)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (на согласование)
# 8 (на согласование)
# [4, 5, 6, 7, 8]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 5
# Элемент найден!
# Участие соглосованно
# 6
# 63209 Ошибка функции
# 30 из 653
# === 81404 ===
# 81404 Мероприятие не найдено
# 31 из 653
# === 91006 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 32 из 653
# === 91835 ===
# 91835 Мероприятие не найдено
# 33 из 653
# === 90800 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 34 из 653
# === 90840 ===
# 90840 Мероприятие не найдено
# 35 из 653
# === 81126 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 36 из 653
# === 63709 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 63709 Ошибка функции
# 37 из 653
# === 90263 ===
# 90263 Мероприятие не найдено
# 38 из 653
# === 81429 ===
# 81429 Мероприятие не найдено
# 39 из 653
# === 90771 ===
# 90771 Мероприятие не найдено
# 40 из 653
# === 90000 ===
# 90000 Мероприятие не найдено
# 41 из 653
# === 91675 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 42 из 653
# === 89965 ===
# 89965 Мероприятие не найдено
# 43 из 653
# === 90952 ===
# 90952 Мероприятие не найдено
# 44 из 653
# === 81102 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (проект)
# 3 (на согласование)
# 4 (на согласование)
# [3, 4]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 81102 Ошибка функции
# 45 из 653
# === 62679 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# [2, 3, 4, 5, 6]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 62679 Ошибка функции
# 46 из 653
# === 89688 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 47 из 653
# === 89798 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 48 из 653
# === 90119 ===
# 90119 Мероприятие не найдено
# 49 из 653
# === 89671 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# [2, 3]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 89671 Ошибка функции
# 50 из 653
# === 90024 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 51 из 653
# === 62101 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 62101 Ошибка функции
# 52 из 653
# === 90017 ===
# 90017 Мероприятие не найдено
# 53 из 653
# === 89803 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 89803 Ошибка функции
# 54 из 653
# === 90021 ===
# 90021 Мероприятие не найдено
# 55 из 653
# === 89531 ===
# 89531 Мероприятие не найдено
# 56 из 653
# === 90264 ===
# 90264 Мероприятие не найдено
# 57 из 653
# === 91433 ===
# 91433 Мероприятие не найдено
# 58 из 653
# === 90019 ===
# 90019 Мероприятие не найдено
# 59 из 653
# === 89895 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 89895 Ошибка функции
# 60 из 653
# === 91097 ===
# 91097 Мероприятие не найдено
# 61 из 653
# === 62475 ===
# 62475 Мероприятие не найдено
# 62 из 653
# === 91032 ===
# 91032 Мероприятие не найдено
# 63 из 653
# === 90002 ===
# 90002 Мероприятие не найдено
# 64 из 653
# === 91730 ===
# 91730 Мероприятие не найдено
# 65 из 653
# === 72391 ===
# 72391 Мероприятие не найдено
# 66 из 653
# === 57561 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# [2, 3]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 57561 Ошибка функции
# 67 из 653
# === 90328 ===
# 90328 Мероприятие не найдено
# 68 из 653
# === 91640 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 91640 Ошибка функции
# 69 из 653
# === 91626 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 70 из 653
# === 76883 ===
# 76883 Мероприятие не найдено
# 71 из 653
# === 87519 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 72 из 653
# === 90092 ===
# 90092 Мероприятие не найдено
# 73 из 653
# === 90082 ===
# 90082 Мероприятие не найдено
# 74 из 653
# === 72421 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 75 из 653
# === 90112 ===
# 90112 Мероприятие не найдено
# 76 из 653
# === 91093 ===
# 91093 Мероприятие не найдено
# 77 из 653
# === 85981 ===
# 85981 Мероприятие не найдено
# 78 из 653
# === 90337 ===
# 5
# 0 (проект)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 90337 Ошибка функции
# 79 из 653
# === 91611 ===
# 91611 Мероприятие не найдено
# 80 из 653
# === 90305 ===
# 90305 Мероприятие не найдено
# 81 из 653
# === 63602 ===
# 63602 Мероприятие не найдено
# 82 из 653
# === 90015 ===
# 90015 Мероприятие не найдено
# 83 из 653
# === 91374 ===
# 91374 Мероприятие не найдено
# 84 из 653
# === 91647 ===
# 91647 Мероприятие не найдено
# 85 из 653
# === 91657 ===
# 91657 Мероприятие не найдено
# 86 из 653
# === 57999 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (проект)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# [2, 4, 5, 6]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 4
# Элемент найден!
# Участие соглосованно
# 5
# 57999 Ошибка функции
# 87 из 653
# === 89673 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 89673 Ошибка функции
# 88 из 653
# === 90016 ===
# 90016 Мероприятие не найдено
# 89 из 653
# === 89678 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 90 из 653
# === 91906 ===
# 91906 Мероприятие не найдено
# 91 из 653
# === 91175 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 92 из 653
# === 91623 ===
# 91623 Мероприятие не найдено
# 93 из 653
# === 89697 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# 4 (на согласование)
# [3, 4]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 89697 Ошибка функции
# 94 из 653
# === 91141 ===
# 91141 Мероприятие не найдено
# 95 из 653
# === 90383 ===
# 90383 Мероприятие не найдено
# 96 из 653
# === 91600 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 97 из 653
# === 59163 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 98 из 653
# === 90746 ===
# 90746 Мероприятие не найдено
# 99 из 653
# === 90528 ===
# 90528 Мероприятие не найдено
# 100 из 653
# === 72461 ===
# 72461 Мероприятие не найдено
# 101 из 653
# === 63346 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 63346 Ошибка функции
# 102 из 653
# === 76755 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 103 из 653
# === 90525 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 104 из 653
# === 80446 ===
# 80446 Мероприятие не найдено
# 105 из 653
# === 91891 ===
# 91891 Мероприятие не найдено
# 106 из 653
# === 62889 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 107 из 653
# === 89850 ===
# 89850 Мероприятие не найдено
# 108 из 653
# === 90110 ===
# 90110 Мероприятие не найдено
# 109 из 653
# === 60095 ===
# 60095 Мероприятие не найдено
# 110 из 653
# === 91601 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 91601 Ошибка функции
# 111 из 653
# === 61482 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 61482 Ошибка функции
# 112 из 653
# === 87340 ===
# 87340 Мероприятие не найдено
# 113 из 653
# === 81768 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 114 из 653
# === 89538 ===
# 89538 Мероприятие не найдено
# 115 из 653
# === 91889 ===
# 91889 Мероприятие не найдено
# 116 из 653
# === 90014 ===
# 90014 Мероприятие не найдено
# 117 из 653
# === 88175 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 118 из 653
# === 61629 ===
# 61629 Мероприятие не найдено
# 119 из 653
# === 89556 ===
# 89556 Мероприятие не найдено
# 120 из 653
# === 89979 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 121 из 653
# === 81109 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 122 из 653
# === 90794 ===
# 90794 Мероприятие не найдено
# 123 из 653
# === 91330 ===
# 91330 Мероприятие не найдено
# 124 из 653
# === 69239 ===
# 69239 Мероприятие не найдено
# 125 из 653
# === 88423 ===
# 88423 Мероприятие не найдено
# 126 из 653
# === 90277 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 90277 Ошибка функции
# 127 из 653
# === 90285 ===
# 90285 Мероприятие не найдено
# 128 из 653
# === 70866 ===
# 70866 Мероприятие не найдено
# 129 из 653
# === 85850 ===
# 85850 Мероприятие не найдено
# 130 из 653
# === 78270 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 131 из 653
# === 90072 ===
# 90072 Мероприятие не найдено
# 132 из 653
# === 90009 ===
# 90009 Мероприятие не найдено
# 133 из 653
# === 85119 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (утверждена)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 134 из 653
# === 62812 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 135 из 653
# === 87870 ===
# 87870 Мероприятие не найдено
# 136 из 653
# === 91001 ===
# 91001 Мероприятие не найдено
# 137 из 653
# === 65767 ===
# 65767 Мероприятие не найдено
# 138 из 653
# === 90863 ===
# 90863 Мероприятие не найдено
# 139 из 653
# === 89551 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# [2, 3, 4, 5, 6]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 89551 Ошибка функции
# 140 из 653
# === 89559 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 89559 Ошибка функции
# 141 из 653
# === 89848 ===
# 89848 Мероприятие не найдено
# 142 из 653
# === 90008 ===
# 90008 Мероприятие не найдено
# 143 из 653
# === 70676 ===
# 70676 Мероприятие не найдено
# 144 из 653
# === 91042 ===
# 91042 Мероприятие не найдено
# 145 из 653
# === 3661 ===
# 3661 Мероприятие не найдено
# 146 из 653
# === 90968 ===
# 6
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# [1, 2, 3, 4, 5]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 90968 Ошибка функции
# 147 из 653
# === 90970 ===
# 90970 Мероприятие не найдено
# 148 из 653
# === 91287 ===
# 8
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (на согласование)
# [3, 4, 5, 6, 7]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 91287 Ошибка функции
# 149 из 653
# === 91300 ===
# 6
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (утверждена)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 91300 Ошибка функции
# 150 из 653
# === 91610 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (на согласование)
# 8 (на согласование)
# 9 (на согласование)
# [2, 3, 4, 5, 6, 7, 8, 9]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 91610 Ошибка функции
# 151 из 653
# === 91617 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (на согласование)
# 8 (на согласование)
# 9 (на согласование)
# [2, 3, 4, 5, 6, 7, 8, 9]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 91617 Ошибка функции
# 152 из 653
# === 91639 ===
# 9
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# [2, 3]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 153 из 653
# === 91645 ===
# 8
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (утверждена)
# [1, 2, 3, 4, 5, 6]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 91645 Ошибка функции
# 154 из 653
# === 91668 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 155 из 653
# === 91673 ===
# 91673 Мероприятие не найдено
# 156 из 653
# === 71412 ===
# 71412 Мероприятие не найдено
# 157 из 653
# === 71666 ===
# 71666 Мероприятие не найдено
# 158 из 653
# === 63668 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 159 из 653
# === 58201 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 160 из 653
# === 91173 ===
# 91173 Мероприятие не найдено
# 161 из 653
# === 86941 ===
# 86941 Мероприятие не найдено
# 162 из 653
# === 91967 ===
# 91967 Мероприятие не найдено
# 163 из 653
# === 88320 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 88320 Ошибка функции
# 164 из 653
# === 84074 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 165 из 653
# === 91867 ===
# 91867 Мероприятие не найдено
# 166 из 653
# === 63760 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 167 из 653
# === 90022 ===
# 90022 Мероприятие не найдено
# 168 из 653
# === 81727 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 169 из 653
# === 64516 ===
# 64516 Мероприятие не найдено
# 170 из 653
# === 83087 ===
# 83087 Мероприятие не найдено
# 171 из 653
# === 91134 ===
# 91134 Мероприятие не найдено
# 172 из 653
# === 63656 ===
# 63656 Мероприятие не найдено
# 173 из 653
# === 62112 ===
# 62112 Мероприятие не найдено
# 174 из 653
# === 69892 ===
# 69892 Мероприятие не найдено
# 175 из 653
# === 68454 ===
# 68454 Мероприятие не найдено
# 176 из 653
# === 91444 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 177 из 653
# === 69076 ===
# 69076 Мероприятие не найдено
# 178 из 653
# === 82995 ===
# 82995 Мероприятие не найдено
# 179 из 653
# === 58764 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 180 из 653
# === 66405 ===
# 66405 Мероприятие не найдено
# 181 из 653
# === 64517 ===
# 64517 Мероприятие не найдено
# 182 из 653
# === 88464 ===
# 88464 Мероприятие не найдено
# 183 из 653
# === 72645 ===
# 72645 Мероприятие не найдено
# 184 из 653
# === 63631 ===
# 63631 Мероприятие не найдено
# 185 из 653
# === 63601 ===
# 63601 Мероприятие не найдено
# 186 из 653
# === 66404 ===
# 66404 Мероприятие не найдено
# 187 из 653
# === 72358 ===
# 72358 Мероприятие не найдено
# 188 из 653
# === 70151 ===
# 70151 Мероприятие не найдено
# 189 из 653
# === 70230 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 190 из 653
# === 63645 ===
# 63645 Мероприятие не найдено
# 191 из 653
# === 71758 ===
# 71758 Мероприятие не найдено
# 192 из 653
# === 80196 ===
# 80196 Мероприятие не найдено
# 193 из 653
# === 73174 ===
# 73174 Мероприятие не найдено
# 194 из 653
# === 58148 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 58148 Ошибка функции
# 195 из 653
# === 87975 ===
# 87975 Мероприятие не найдено
# 196 из 653
# === 77035 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 197 из 653
# === 70465 ===
# 70465 Мероприятие не найдено
# 198 из 653
# === 89791 ===
# 89791 Мероприятие не найдено
# 199 из 653
# === 58314 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 58314 Ошибка функции
# 200 из 653
# === 58226 ===
# 58226 Мероприятие не найдено
# 201 из 653
# === 91323 ===
# 91323 Мероприятие не найдено
# 202 из 653
# === 76764 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 203 из 653
# === 91376 ===
# 91376 Мероприятие не найдено
# 204 из 653
# === 66477 ===
# 66477 Мероприятие не найдено
# 205 из 653
# === 86490 ===
# 86490 Мероприятие не найдено
# 206 из 653
# === 63875 ===
# 63875 Мероприятие не найдено
# 207 из 653
# === 91839 ===
# 91839 Мероприятие не найдено
# 208 из 653
# === 68514 ===
# 68514 Мероприятие не найдено
# 209 из 653
# === 62183 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 62183 Ошибка функции
# 210 из 653
# === 61478 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 211 из 653
# === 79825 ===
# 79825 Мероприятие не найдено
# 212 из 653
# === 79824 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 213 из 653
# === 87024 ===
# 87024 Мероприятие не найдено
# 214 из 653
# === 69191 ===
# 69191 Мероприятие не найдено
# 215 из 653
# === 73182 ===
# 73182 Мероприятие не найдено
# 216 из 653
# === 68386 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 68386 Ошибка функции
# 217 из 653
# === 61710 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 218 из 653
# === 91436 ===
# 91436 Мероприятие не найдено
# 219 из 653
# === 78864 ===
# 78864 Мероприятие не найдено
# 220 из 653
# === 81528 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 81528 Ошибка функции
# 221 из 653
# === 91972 ===
# 91972 Мероприятие не найдено
# 222 из 653
# === 68911 ===
# 68911 Мероприятие не найдено
# 223 из 653
# === 86824 ===
# 86824 Мероприятие не найдено
# 224 из 653
# === 91146 ===
# 91146 Мероприятие не найдено
# 225 из 653
# === 65780 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 226 из 653
# === 79522 ===
# 79522 Мероприятие не найдено
# 227 из 653
# === 64191 ===
# 64191 Мероприятие не найдено
# 228 из 653
# === 86977 ===
# 86977 Мероприятие не найдено
# 229 из 653
# === 90969 ===
# 90969 Мероприятие не найдено
# 230 из 653
# === 71434 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [2, 3, 4]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 71434 Ошибка функции
# 231 из 653
# === 87480 ===
# 87480 Мероприятие не найдено
# 232 из 653
# === 79482 ===
# 79482 Мероприятие не найдено
# 233 из 653
# === 91216 ===
# 91216 Мероприятие не найдено
# 234 из 653
# === 87228 ===
# 87228 Мероприятие не найдено
# 235 из 653
# === 91905 ===
# 91905 Мероприятие не найдено
# 236 из 653
# === 58886 ===
# 58886 Мероприятие не найдено
# 237 из 653
# === 66402 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 238 из 653
# === 91215 ===
# 91215 Мероприятие не найдено
# 239 из 653
# === 90011 ===
# 90011 Мероприятие не найдено
# 240 из 653
# === 68456 ===
# 68456 Мероприятие не найдено
# 241 из 653
# === 56718 ===
# 56718 Мероприятие не найдено
# 242 из 653
# === 91214 ===
# 91214 Мероприятие не найдено
# 243 из 653
# === 68319 ===
# 68319 Мероприятие не найдено
# 244 из 653
# === 79495 ===
# 79495 Мероприятие не найдено
# 245 из 653
# === 77523 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 246 из 653
# === 90071 ===
# 90071 Мероприятие не найдено
# 247 из 653
# === 57158 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 248 из 653
# === 59318 ===
# 59318 Мероприятие не найдено
# 249 из 653
# === 90325 ===
# 90325 Мероприятие не найдено
# 250 из 653
# === 90074 ===
# 90074 Мероприятие не найдено
# 251 из 653
# === 60201 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 60201 Ошибка функции
# 252 из 653
# === 68883 ===
# 68883 Мероприятие не найдено
# 253 из 653
# === 59062 ===
# 59062 Мероприятие не найдено
# 254 из 653
# === 72276 ===
# 72276 Мероприятие не найдено
# 255 из 653
# === 60212 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 60212 Ошибка функции
# 256 из 653
# === 87293 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 257 из 653
# === 86943 ===
# 86943 Мероприятие не найдено
# 258 из 653
# === 68605 ===
# 68605 Мероприятие не найдено
# 259 из 653
# === 68257 ===
# 68257 Мероприятие не найдено
# 260 из 653
# === 60004 ===
# 60004 Мероприятие не найдено
# 261 из 653
# === 89970 ===
# 89970 Мероприятие не найдено
# 262 из 653
# === 85648 ===
# 85648 Мероприятие не найдено
# 263 из 653
# === 87235 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 87235 Ошибка функции
# 264 из 653
# === 56332 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 56332 Ошибка функции
# 265 из 653
# === 60003 ===
# 60003 Мероприятие не найдено
# 266 из 653
# === 58687 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 58687 Ошибка функции
# 267 из 653
# === 78321 ===
# 78321 Мероприятие не найдено
# 268 из 653
# === 57433 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 57433 Ошибка функции
# 269 из 653
# === 79077 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 79077 Ошибка функции
# 270 из 653
# === 58836 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 271 из 653
# === 81075 ===
# 81075 Мероприятие не найдено
# 272 из 653
# === 59707 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 273 из 653
# === 62207 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 274 из 653
# === 56925 ===
# 56925 Мероприятие не найдено
# 275 из 653
# === 91667 ===
# 91667 Мероприятие не найдено
# 276 из 653
# === 68227 ===
# 68227 Мероприятие не найдено
# 277 из 653
# === 1099 ===
# 1099 Мероприятие не найдено
# 278 из 653
# === 1095 ===
# 1095 Мероприятие не найдено
# 279 из 653
# === 56715 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 280 из 653
# === 58022 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 281 из 653
# === 63486 ===
# 63486 Мероприятие не найдено
# 282 из 653
# === 60644 ===
# 60644 Мероприятие не найдено
# 283 из 653
# === 57135 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 284 из 653
# === 71268 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 71268 Ошибка функции
# 285 из 653
# === 89522 ===
# 89522 Мероприятие не найдено
# 286 из 653
# === 87179 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 287 из 653
# === 58864 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# [2, 3]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 58864 Ошибка функции
# 288 из 653
# === 71467 ===
# 71467 Мероприятие не найдено
# 289 из 653
# === 57034 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 57034 Ошибка функции
# 290 из 653
# === 67537 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 67537 Ошибка функции
# 291 из 653
# === 87065 ===
# 87065 Мероприятие не найдено
# 292 из 653
# === 57342 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 293 из 653
# === 90377 ===
# 90377 Мероприятие не найдено
# 294 из 653
# === 86201 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 295 из 653
# === 59511 ===
# 59511 Мероприятие не найдено
# 296 из 653
# === 59621 ===
# 59621 Мероприятие не найдено
# 297 из 653
# === 78582 ===
# 78582 Мероприятие не найдено
# 298 из 653
# === 87224 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 87224 Ошибка функции
# 299 из 653
# === 87221 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 87221 Ошибка функции
# 300 из 653
# === 63587 ===
# 63587 Мероприятие не найдено
# 301 из 653
# === 63584 ===
# 63584 Мероприятие не найдено
# 302 из 653
# === 63753 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 303 из 653
# === 59496 ===
# 59496 Мероприятие не найдено
# 304 из 653
# === 78332 ===
# 78332 Мероприятие не найдено
# 305 из 653
# === 86875 ===
# 86875 Мероприятие не найдено
# 306 из 653
# === 68279 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 307 из 653
# === 87252 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 308 из 653
# === 81765 ===
# 81765 Мероприятие не найдено
# 309 из 653
# === 62407 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 310 из 653
# === 59878 ===
# 59878 Мероприятие не найдено
# 311 из 653
# === 59644 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 59644 Ошибка функции
# 312 из 653
# === 59224 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 59224 Ошибка функции
# 313 из 653
# === 53289 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 314 из 653
# === 86757 ===
# 86757 Мероприятие не найдено
# 315 из 653
# === 72145 ===
# 72145 Мероприятие не найдено
# 316 из 653
# === 81789 ===
# 81789 Мероприятие не найдено
# 317 из 653
# === 90321 ===
# 90321 Мероприятие не найдено
# 318 из 653
# === 77823 ===
# 77823 Мероприятие не найдено
# 319 из 653
# === 54660 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 320 из 653
# === 66933 ===
# 66933 Мероприятие не найдено
# 321 из 653
# === 90023 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 322 из 653
# === 91056 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 323 из 653
# === 91155 ===
# 91155 Мероприятие не найдено
# 324 из 653
# === 63767 ===
# 63767 Мероприятие не найдено
# 325 из 653
# === 72680 ===
# 72680 Мероприятие не найдено
# 326 из 653
# === 90625 ===
# 90625 Мероприятие не найдено
# 327 из 653
# === 77011 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 328 из 653
# === 86905 ===
# 86905 Мероприятие не найдено
# 329 из 653
# === 77012 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (проект)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 330 из 653
# === 90319 ===
# 90319 Мероприятие не найдено
# 331 из 653
# === 90173 ===
# 90173 Мероприятие не найдено
# 332 из 653
# === 85721 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 333 из 653
# === 82726 ===
# 82726 Мероприятие не найдено
# 334 из 653
# === 77932 ===
# 77932 Мероприятие не найдено
# 335 из 653
# === 91396 ===
# 91396 Мероприятие не найдено
# 336 из 653
# === 81770 ===
# 81770 Мероприятие не найдено
# 337 из 653
# === 72043 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 338 из 653
# === 67319 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 339 из 653
# === 67317 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 340 из 653
# === 71374 ===
# 71374 Мероприятие не найдено
# 341 из 653
# === 82841 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 342 из 653
# === 56923 ===
# 4
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [0, 1, 2, 3]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 56923 Ошибка функции
# 343 из 653
# === 63290 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 344 из 653
# === 91094 ===
# 91094 Мероприятие не найдено
# 345 из 653
# === 58835 ===
# 58835 Мероприятие не найдено
# 346 из 653
# === 78561 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 347 из 653
# === 77669 ===
# 4
# 0 (проект)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# [2, 3]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 77669 Ошибка функции
# 348 из 653
# === 90819 ===
# 90819 Мероприятие не найдено
# 349 из 653
# === 64002 ===
# 64002 Мероприятие не найдено
# 350 из 653
# === 59116 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 351 из 653
# === 68757 ===
# 68757 Мероприятие не найдено
# 352 из 653
# === 59125 ===
# 59125 Мероприятие не найдено
# 353 из 653
# === 61533 ===
# 61533 Мероприятие не найдено
# 354 из 653
# === 59402 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 355 из 653
# === 57319 ===
# 57319 Мероприятие не найдено
# 356 из 653
# === 59035 ===
# 59035 Мероприятие не найдено
# 357 из 653
# === 81072 ===
# 81072 Мероприятие не найдено
# 358 из 653
# === 65801 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (на согласование)
# 8 (на согласование)
# [2, 3, 4, 5, 6, 7, 8]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 4
# 65801 Ошибка функции
# 359 из 653
# === 86568 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 360 из 653
# === 59457 ===
# 59457 Мероприятие не найдено
# 361 из 653
# === 81073 ===
# 81073 Мероприятие не найдено
# 362 из 653
# === 89871 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 89871 Ошибка функции
# 363 из 653
# === 58919 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 364 из 653
# === 58834 ===
# 58834 Мероприятие не найдено
# 365 из 653
# === 56891 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 366 из 653
# === 67888 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 367 из 653
# === 78269 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 368 из 653
# === 63669 ===
# 63669 Мероприятие не найдено
# 369 из 653
# === 91211 ===
# 91211 Мероприятие не найдено
# 370 из 653
# === 86484 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 86484 Ошибка функции
# 371 из 653
# === 57273 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 57273 Ошибка функции
# 372 из 653
# === 57121 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 373 из 653
# === 59024 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (утверждена)
# 3 (на согласование)
# [1, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 374 из 653
# === 78245 ===
# 78245 Мероприятие не найдено
# 375 из 653
# === 59521 ===
# 59521 Мероприятие не найдено
# 376 из 653
# === 78400 ===
# 78400 Мероприятие не найдено
# 377 из 653
# === 67959 ===
# 67959 Мероприятие не найдено
# 378 из 653
# === 57036 ===
# 57036 Мероприятие не найдено
# 379 из 653
# === 72672 ===
# 72672 Мероприятие не найдено
# 380 из 653
# === 63990 ===
# 63990 Мероприятие не найдено
# 381 из 653
# === 56892 ===
# 3
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# [0, 1, 2]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 56892 Ошибка функции
# 382 из 653
# === 84465 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 383 из 653
# === 86183 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 384 из 653
# === 68094 ===
# 68094 Мероприятие не найдено
# 385 из 653
# === 58994 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 58994 Ошибка функции
# 386 из 653
# === 86598 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 387 из 653
# === 59567 ===
# 59567 Мероприятие не найдено
# 388 из 653
# === 86588 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 389 из 653
# === 71280 ===
# 71280 Мероприятие не найдено
# 390 из 653
# === 57087 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 57087 Ошибка функции
# 391 из 653
# === 84167 ===
# 84167 Мероприятие не найдено
# 392 из 653
# === 78132 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 393 из 653
# === 62324 ===
# 62324 Мероприятие не найдено
# 394 из 653
# === 56262 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [1, 2, 3, 4]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 56262 Ошибка функции
# 395 из 653
# === 59227 ===
# 59227 Мероприятие не найдено
# 396 из 653
# === 91078 ===
# 91078 Мероприятие не найдено
# 397 из 653
# === 79068 ===
# 79068 Мероприятие не найдено
# 398 из 653
# === 91720 ===
# 91720 Мероприятие не найдено
# 399 из 653
# === 90752 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 400 из 653
# === 91207 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 401 из 653
# === 81556 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 402 из 653
# === 64439 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 403 из 653
# === 86330 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 86330 Ошибка функции
# 404 из 653
# === 64434 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 405 из 653
# === 64455 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 406 из 653
# === 64461 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 407 из 653
# === 57337 ===
# 6
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [0, 1, 2, 3, 4]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 57337 Ошибка функции
# 408 из 653
# === 63684 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 409 из 653
# === 58398 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 58398 Ошибка функции
# 410 из 653
# === 64451 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 411 из 653
# === 80725 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 412 из 653
# === 66952 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 413 из 653
# === 71303 ===
# 3
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# [0, 1, 2]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 71303 Ошибка функции
# 414 из 653
# === 59071 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 415 из 653
# === 78272 ===
# 3
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# [0, 1, 2]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 78272 Ошибка функции
# 416 из 653
# === 58322 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 417 из 653
# === 59323 ===
# 5
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [0, 1, 2, 3, 4]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 59323 Ошибка функции
# 418 из 653
# === 86584 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 86584 Ошибка функции
# 419 из 653
# === 90948 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 420 из 653
# === 64382 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 421 из 653
# === 64454 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 422 из 653
# === 78351 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 423 из 653
# === 86261 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 424 из 653
# === 56883 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 56883 Ошибка функции
# 425 из 653
# === 64460 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 426 из 653
# === 68011 ===
# 5
# 0 (проект)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# [1, 2, 3]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 68011 Ошибка функции
# 427 из 653
# === 64426 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 428 из 653
# === 74724 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 429 из 653
# === 81667 ===
# 4
# 0 (на согласование)
# 1 (на согласование)
# 2 (на согласование)
# [0, 1, 2]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 81667 Ошибка функции
# 430 из 653
# === 91061 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 431 из 653
# === 64453 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 432 из 653
# === 64456 ===
# 64456 Мероприятие не найдено
# 433 из 653
# === 64446 ===
# 2
# 0 (на согласование)
# 1 (на согласование)
# [0, 1]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1
# 64446 Ошибка функции
# 434 из 653
# === 64381 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 435 из 653
# === 64379 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 436 из 653
# === 82673 ===
# 82673 Мероприятие не найдено
# 437 из 653
# === 90027 ===
# 90027 Мероприятие не найдено
# 438 из 653
# === 86472 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 439 из 653
# === 86372 ===
# 86372 Мероприятие не найдено
# 440 из 653
# === 90054 ===
# 90054 Мероприятие не найдено
# 441 из 653
# === 62897 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (проект)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 442 из 653
# === 62813 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 443 из 653
# === 55303 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 55303 Ошибка функции
# 444 из 653
# === 57119 ===
# 3
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# [1, 2]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# 57119 Ошибка функции
# 445 из 653
# === 60048 ===
# 60048 Мероприятие не найдено
# 446 из 653
# === 57205 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 447 из 653
# === 58646 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 448 из 653
# === 86374 ===
# 86374 Мероприятие не найдено
# 449 из 653
# === 80909 ===
# 80909 Мероприятие не найдено
# 450 из 653
# === 77879 ===
# 6
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# [1, 2, 3, 4, 5]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 77879 Ошибка функции
# 451 из 653
# === 63275 ===
# 63275 Мероприятие не найдено
# 452 из 653
# === 59596 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 453 из 653
# === 59593 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 454 из 653
# === 59595 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 455 из 653
# === 61416 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 456 из 653
# === 56885 ===
# 56885 Мероприятие не найдено
# 457 из 653
# === 78063 ===
# 78063 Мероприятие не найдено
# 458 из 653
# === 59145 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 459 из 653
# === 77909 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 460 из 653
# === 89753 ===
# 89753 Мероприятие не найдено
# 461 из 653
# === 78110 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 462 из 653
# === 80993 ===
# 80993 Мероприятие не найдено
# 463 из 653
# === 86208 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 464 из 653
# === 56914 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# [2, 3, 4]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 56914 Ошибка функции
# 465 из 653
# === 57068 ===
# 8
# 0 (утверждена)
# 1 (на согласование)
# 2 (на согласование)
# 3 (на согласование)
# 4 (на согласование)
# 5 (на согласование)
# 6 (на согласование)
# 7 (на согласование)
# [1, 2, 3, 4, 5, 6, 7]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 2
# Элемент найден!
# Участие соглосованно
# 3
# 57068 Ошибка функции
# 466 из 653
# === 59049 ===
# 59049 Мероприятие не найдено
# 467 из 653
# === 67292 ===
# 67292 Мероприятие не найдено
# 468 из 653
# === 91206 ===
# 91206 Мероприятие не найдено
# 469 из 653
# === 63691 ===
# 63691 Мероприятие не найдено
# 470 из 653
# === 67667 ===
# 67667 Мероприятие не найдено
# 471 из 653
# === 91003 ===
# 91003 Мероприятие не найдено
# 472 из 653
# === 62582 ===
# 62582 Мероприятие не найдено
# 473 из 653
# === 81837 ===
# 81837 Мероприятие не найдено
# 474 из 653
# === 81833 ===
# 81833 Мероприятие не найдено
# 475 из 653
# === 86578 ===
# 86578 Мероприятие не найдено
# 476 из 653
# === 57573 ===
# 57573 Мероприятие не найдено
# 477 из 653
# === 56889 ===
# 56889 Мероприятие не найдено
# 478 из 653
# === 56755 ===
# 56755 Мероприятие не найдено
# 479 из 653
# === 56261 ===
# 56261 Мероприятие не найдено
# 480 из 653
# === 71741 ===
# 71741 Мероприятие не найдено
# 481 из 653
# === 67333 ===
# 67333 Мероприятие не найдено
# 482 из 653
# === 89842 ===
# 89842 Мероприятие не найдено
# 483 из 653
# === 91101 ===
# 91101 Мероприятие не найдено
# 484 из 653
# === 90785 ===
# 90785 Мероприятие не найдено
# 485 из 653
# === 78210 ===
# 78210 Мероприятие не найдено
# 486 из 653
# === 57385 ===
# 57385 Мероприятие не найдено
# 487 из 653
# === 91725 ===
# 91725 Мероприятие не найдено
# 488 из 653
# === 56890 ===
# 56890 Мероприятие не найдено
# 489 из 653
# === 77974 ===
# 77974 Мероприятие не найдено
# 490 из 653
# === 77590 ===
# 77590 Мероприятие не найдено
# 491 из 653
# === 56652 ===
# 56652 Мероприятие не найдено
# 492 из 653
# === 90286 ===
# 90286 Мероприятие не найдено
# 493 из 653
# === 62651 ===
# 62651 Мероприятие не найдено
# 494 из 653
# === 63262 ===
# 63262 Мероприятие не найдено
# 495 из 653
# === 77779 ===
# 77779 Мероприятие не найдено
# 496 из 653
# === 71677 ===
# 71677 Мероприятие не найдено
# 497 из 653
# === 91073 ===
# 91073 Мероприятие не найдено
# 498 из 653
# === 77564 ===
# 77564 Мероприятие не найдено
# 499 из 653
# === 72627 ===
# 72627 Мероприятие не найдено
# 500 из 653
# === 66685 ===
# 66685 Мероприятие не найдено
# 501 из 653
# === 63764 ===
# 63764 Мероприятие не найдено
# 502 из 653
# === 66686 ===
# 66686 Мероприятие не найдено
# 503 из 653
# === 53970 ===
# 53970 Мероприятие не найдено
# 504 из 653
# === 85790 ===
# 85790 Мероприятие не найдено
# 505 из 653
# === 71210 ===
# 71210 Мероприятие не найдено
# 506 из 653
# === 89547 ===
# 89547 Мероприятие не найдено
# 507 из 653
# === 90897 ===
# 90897 Мероприятие не найдено
# 508 из 653
# === 90938 ===
# 90938 Мероприятие не найдено
# 509 из 653
# === 56846 ===
# 56846 Мероприятие не найдено
# 510 из 653
# === 63810 ===
# 63810 Мероприятие не найдено
# 511 из 653
# === 3099 ===
# 3099 Мероприятие не найдено
# 512 из 653
# === 78299 ===
# 78299 Мероприятие не найдено
# 513 из 653
# === 63181 ===
# 63181 Мероприятие не найдено
# 514 из 653
# === 54770 ===
# 54770 Мероприятие не найдено
# 515 из 653
# === 66622 ===
# 66622 Мероприятие не найдено
# 516 из 653
# === 78297 ===
# 78297 Мероприятие не найдено
# 517 из 653
# === 66492 ===
# 66492 Мероприятие не найдено
# 518 из 653
# === 63117 ===
# 63117 Мероприятие не найдено
# 519 из 653
# === 57367 ===
# 57367 Мероприятие не найдено
# 520 из 653
# === 58720 ===
# 58720 Мероприятие не найдено
# 521 из 653
# === 56326 ===
# 56326 Мероприятие не найдено
# 522 из 653
# === 89998 ===
# 89998 Мероприятие не найдено
# 523 из 653
# === 81076 ===
# 81076 Мероприятие не найдено
# 524 из 653
# === 62346 ===
# 62346 Мероприятие не найдено
# 525 из 653
# === 71473 ===
# 71473 Мероприятие не найдено
# 526 из 653
# === 59092 ===
# 59092 Мероприятие не найдено
# 527 из 653
# === 81014 ===
# 81014 Мероприятие не найдено
# 528 из 653
# === 57244 ===
# 57244 Мероприятие не найдено
# 529 из 653
# === 61663 ===
# 61663 Мероприятие не найдено
# 530 из 653
# === 56994 ===
# 56994 Мероприятие не найдено
# 531 из 653
# === 67373 ===
# 67373 Мероприятие не найдено
# 532 из 653
# === 56591 ===
# 56591 Мероприятие не найдено
# 533 из 653
# === 85759 ===
# 85759 Мероприятие не найдено
# 534 из 653
# === 57270 ===
# 57270 Мероприятие не найдено
# 535 из 653
# === 61451 ===
# 61451 Мероприятие не найдено
# 536 из 653
# === 57511 ===
# 57511 Мероприятие не найдено
# 537 из 653
# === 89694 ===
# 89694 Мероприятие не найдено
# 538 из 653
# === 90817 ===
# 90817 Мероприятие не найдено
# 539 из 653
# === 67387 ===
# 67387 Мероприятие не найдено
# 540 из 653
# === 71408 ===
# 71408 Мероприятие не найдено
# 541 из 653
# === 67765 ===
# 67765 Мероприятие не найдено
# 542 из 653
# === 57049 ===
# 57049 Мероприятие не найдено
# 543 из 653
# === 77880 ===
# 77880 Мероприятие не найдено
# 544 из 653
# === 58170 ===
# 58170 Мероприятие не найдено
# 545 из 653
# === 63925 ===
# 63925 Мероприятие не найдено
# 546 из 653
# === 57259 ===
# 57259 Мероприятие не найдено
# 547 из 653
# === 56803 ===
# 56803 Мероприятие не найдено
# 548 из 653
# === 90145 ===
# 90145 Мероприятие не найдено
# 549 из 653
# === 61398 ===
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-3-31df6745ec94> in <module>
#       1 import new_ias_main_function as ias
# ----> 2 ias.paty_approve(2025, df)
#
# ~\DevConda\IASControl\new_ias_main_function.py in paty_approve(name_period, df)
#      65    ias.status_paty()
#      66    #======= Цикл перебора мероприятий
# ---> 67    ias.list_application(df, 'agree_paty', 'мероприятия')
#      68    return ias.nan_application
#      69
#
# ~\DevConda\IASControl\new_ias_basic_function.py in list_application(df, fun_name, razdel, name_agree)
#     314       print('===', i, '===')
#     315       hrefList = []
# --> 316       search_number(i, razdel)
#     317       try:
#     318          expand_event()
#
# ~\DevConda\IASControl\new_ias_basic_function.py in search_number(x, razdel)
#     163          "//app-events-app-section-header/form[1]/div[2]/div[2]/app-search-input[1]/div[1]/input[1]")
#     164    elif razdel == 'мероприятия':
# --> 165       find = driver.find_element(By.XPATH,
#     166          "//app-events-section-header/form[1]/div[2]/div[2]/app-search-input[1]/div[1]/input[1]")
#     167    find.clear()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//app-events-section-header/form[1]/div[2]/div[2]/app-search-input[1]/div[1]/input[1]"}
#   (Session info: chrome=129.0.6668.101); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF67459B125+29573]
# 	(No symbol) [0x00007FF67450FF50]
# 	(No symbol) [0x00007FF6743CB6EA]
# 	(No symbol) [0x00007FF67441F815]
# 	(No symbol) [0x00007FF67441FA6C]
# 	(No symbol) [0x00007FF67446B917]
# 	(No symbol) [0x00007FF67444733F]
# 	(No symbol) [0x00007FF6744686BC]
# 	(No symbol) [0x00007FF6744470A3]
# 	(No symbol) [0x00007FF6744112DF]
# 	(No symbol) [0x00007FF674412441]
# 	GetHandleVerifier [0x00007FF6748CC76D+3377613]
# 	GetHandleVerifier [0x00007FF674917B67+3685831]
# 	GetHandleVerifier [0x00007FF67490CF8B+3641835]
# 	GetHandleVerifier [0x00007FF67465B2A6+816390]
# 	(No symbol) [0x00007FF67451B25F]
# 	(No symbol) [0x00007FF674517084]
# 	(No symbol) [0x00007FF674517220]
# 	(No symbol) [0x00007FF67450607F]
# 	BaseThreadInitThunk [0x00007FFE17B97034+20]
# 	RtlUserThreadStart [0x00007FFE18522651+33]

# %%
df = (df[df['Реестр №'] < 0])
df.to_excel(file_name, index=False)
