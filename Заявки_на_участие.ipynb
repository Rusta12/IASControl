# %%
import pandas as pd
import numpy as np
import os
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
file_name = r"C:/DataIAS/Список спортмероприятий (участие).xlsx"
xls = pd.ExcelFile(file_name)
df = pd.read_excel(xls, 'Sheet1')

# %% [markdown]
# ias.search_party(df_list)

# %%
import new_ias_main_function as ias
ias.paty_approve(2025, df)
# Out:
# 0 из 77
# === 81017 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 1 из 77
# === 63209 ===
# 10
# 0 (утверждена)
# 1 (проект)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# []  Это список согла!
# 2 из 77
# === 61504 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 3 из 77
# === 70792 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# [5]  Это список согла!
# 5
# Элемент найден!
# 4 из 77
# === 91578 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (на согласование)
# [4, 5]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 5
# Элемент найден!
# Участие соглосованно
# 5 из 77
# === 90289 ===
# 10
# 0 (проект)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# 9 (утверждена)
# []  Это список согла!
# 6 из 77
# === 91610 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# 9 (на согласование)
# [9]  Это список согла!
# 9
# Элемент найден!
# Участие соглосованно
# 7 из 77
# === 91617 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# 9 (утверждена)
# []  Это список согла!
# 8 из 77
# === 62482 ===
# 62482 Ошибка функции
# 9 из 77
# === 62932 ===
# 62932 Мероприятие не найдено
# 10 из 77
# === 56660 ===
# 56660 Мероприятие не найдено
# 11 из 77
# === 65802 ===
# 65802 Мероприятие не найдено
# 12 из 77
# === 68911 ===
# 68911 Мероприятие не найдено
# 13 из 77
# === 63088 ===
# 63088 Мероприятие не найдено
# 14 из 77
# === 79576 ===
# 79576 Мероприятие не найдено
# 15 из 77
# === 79021 ===
# 79021 Мероприятие не найдено
# 16 из 77
# === 68906 ===
# 68906 Мероприятие не найдено
# 17 из 77
# === 56980 ===
# 56980 Мероприятие не найдено
# 18 из 77
# === 65806 ===
# 65806 Мероприятие не найдено
# 19 из 77
# === 57034 ===
# 57034 Мероприятие не найдено
# 20 из 77
# === 59650 ===
# 59650 Мероприятие не найдено
# 21 из 77
# === 59649 ===
# 59649 Мероприятие не найдено
# 22 из 77
# === 57553 ===
# 57553 Мероприятие не найдено
# 23 из 77
# === 58917 ===
# 58917 Мероприятие не найдено
# 24 из 77
# === 57108 ===
# 57108 Мероприятие не найдено
# 25 из 77
# === 78459 ===
# 78459 Мероприятие не найдено
# 26 из 77
# === 78244 ===
# 78244 Мероприятие не найдено
# 27 из 77
# === 77667 ===
# 77667 Мероприятие не найдено
# 28 из 77
# === 57103 ===
# 57103 Мероприятие не найдено
# 29 из 77
# === 65801 ===
# 65801 Мероприятие не найдено
# 30 из 77
# === 78136 ===
# 78136 Мероприятие не найдено
# 31 из 77
# === 67877 ===
# 67877 Мероприятие не найдено
# 32 из 77
# === 56859 ===
# 56859 Мероприятие не найдено
# 33 из 77
# === 65803 ===
# 65803 Мероприятие не найдено
# 34 из 77
# === 78255 ===
# 78255 Мероприятие не найдено
# 35 из 77
# === 58465 ===
# 58465 Мероприятие не найдено
# 36 из 77
# === 86491 ===
# 86491 Мероприятие не найдено
# 37 из 77
# === 59323 ===
# 59323 Мероприятие не найдено
# 38 из 77
# === 57533 ===
# 57533 Мероприятие не найдено
# 39 из 77
# === 57068 ===
# 57068 Мероприятие не найдено
# 40 из 77
# === 81301 ===
# 81301 Мероприятие не найдено
# 41 из 77
# === 57268 ===
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-3-31df6745ec94> in <module>
#       1 import new_ias_main_function as ias
# ----> 2 ias.paty_approve(2025, df)
#
# ~\DevConda\IASControl\new_ias_main_function.py in paty_approve(name_period, df)
#      82    ias.status_paty()
#      83    #======= Цикл перебора мероприятий
# ---> 84    ias.list_application(df, 'agree_paty', 'мероприятия')
#      85    return ias.nan_application
#      86
#
# ~\DevConda\IASControl\new_ias_basic_function.py in list_application(df, fun_name, razdel, name_agree)
#     332       print('===', i, '===')
#     333       hrefList = []
# --> 334       search_number(i, razdel)
#     335       try:
#     336          expand_event()
#
# ~\DevConda\IASControl\new_ias_basic_function.py in search_number(x, razdel)
#     181          "//app-events-app-section-header/form[1]/div[2]/div[2]/app-search-input[1]/div[1]/input[1]")
#     182    elif razdel == 'мероприятия':
# --> 183       find = driver.find_element(By.XPATH,
#     184          "//app-events-section-header/form[1]/div[2]/div[2]/app-search-input[1]/div[1]/input[1]")
#     185    find.clear()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//app-events-section-header/form[1]/div[2]/div[2]/app-search-input[1]/div[1]/input[1]"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7F06AB125+29573]
# 	(No symbol) [0x00007FF7F061FF50]
# 	(No symbol) [0x00007FF7F04DB6EA]
# 	(No symbol) [0x00007FF7F052F815]
# 	(No symbol) [0x00007FF7F052FA6C]
# 	(No symbol) [0x00007FF7F057B917]
# 	(No symbol) [0x00007FF7F055733F]
# 	(No symbol) [0x00007FF7F05786BC]
# 	(No symbol) [0x00007FF7F05570A3]
# 	(No symbol) [0x00007FF7F05212DF]
# 	(No symbol) [0x00007FF7F0522441]
# 	GetHandleVerifier [0x00007FF7F09DC76D+3377613]
# 	GetHandleVerifier [0x00007FF7F0A27B67+3685831]
# 	GetHandleVerifier [0x00007FF7F0A1CF8B+3641835]
# 	GetHandleVerifier [0x00007FF7F076B2A6+816390]
# 	(No symbol) [0x00007FF7F062B25F]
# 	(No symbol) [0x00007FF7F0627084]
# 	(No symbol) [0x00007FF7F0627220]
# 	(No symbol) [0x00007FF7F061607F]
# 	BaseThreadInitThunk [0x00007FFF7A957034+20]
# 	RtlUserThreadStart [0x00007FFF7AEC2651+33]

# %%
df = (df[df['Реестр №'] < 0])
df.to_excel(file_name, index=False)
