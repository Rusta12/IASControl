# %%
import pandas as pd
import numpy as np
import os
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
file_name = r"C:/DataIAS/Список спортмероприятий (участие).xlsx"
xls = pd.ExcelFile(file_name)
df = pd.read_excel(xls, 'Sheet1')

# %% [markdown]
# ias.search_party(df_list)

# %%
import new_ias_main_function as ias
ias.paty_approve(2025, df)
# Out:
# 0 из 56
# === 63209 ===
# 63209 Мероприятие не найдено
# 1 из 56
# === 89687 ===
# 89687 Мероприятие не найдено
# 2 из 56
# === 70792 ===
# 70792 Мероприятие не найдено
# 3 из 56
# === 90289 ===
# 90289 Мероприятие не найдено
# 4 из 56
# === 91617 ===
# 91617 Мероприятие не найдено
# 5 из 56
# === 62482 ===
# 62482 Мероприятие не найдено
# 6 из 56
# === 62932 ===
# 62932 Мероприятие не найдено
# 7 из 56
# === 56660 ===
# 56660 Мероприятие не найдено
# 8 из 56
# === 65802 ===
# 65802 Мероприятие не найдено
# 9 из 56
# === 68911 ===
# 68911 Мероприятие не найдено
# 10 из 56
# === 63088 ===
# 63088 Мероприятие не найдено
# 11 из 56
# === 79576 ===
# 79576 Мероприятие не найдено
# 12 из 56
# === 79021 ===
# 79021 Мероприятие не найдено
# 13 из 56
# === 56980 ===
# 56980 Мероприятие не найдено
# 14 из 56
# === 65806 ===
# 65806 Мероприятие не найдено
# 15 из 56
# === 59650 ===
# 59650 Мероприятие не найдено
# 16 из 56
# === 59649 ===
# 59649 Мероприятие не найдено
# 17 из 56
# === 58917 ===
# 58917 Мероприятие не найдено
# 18 из 56
# === 57108 ===
# 57108 Мероприятие не найдено
# 19 из 56
# === 57103 ===
# 57103 Мероприятие не найдено
# 20 из 56
# === 65801 ===
# 65801 Мероприятие не найдено
# 21 из 56
# === 65803 ===
# 65803 Мероприятие не найдено
# 22 из 56
# === 59323 ===
# 59323 Мероприятие не найдено
# 23 из 56
# === 57068 ===
# 57068 Мероприятие не найдено
# 24 из 56
# === 67790 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 25 из 56
# === 81595 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (на согласование)
# [4, 5]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 5
# Элемент найден!
# Участие соглосованно
# 26 из 56
# === 57091 ===
# 57091 Мероприятие не найдено
# 27 из 56
# === 80887 ===
# 80887 Мероприятие не найдено
# 28 из 56
# === 56744 ===
# 56744 Мероприятие не найдено
# 29 из 56
# === 56653 ===
# 56653 Мероприятие не найдено
# 30 из 56
# === 62709 ===
# 62709 Мероприятие не найдено
# 31 из 56
# === 57669 ===
# 57669 Мероприятие не найдено
# 32 из 56
# === 59942 ===
# 59942 Мероприятие не найдено
# 33 из 56
# === 85654 ===
# 85654 Мероприятие не найдено
# 34 из 56
# === 61475 ===
# 61475 Мероприятие не найдено
# 35 из 56
# === 56420 ===
# 56420 Мероприятие не найдено
# 36 из 56
# === 66695 ===
# 66695 Мероприятие не найдено
# 37 из 56
# === 85303 ===
# 85303 Мероприятие не найдено
# 38 из 56
# === 61471 ===
# 61471 Мероприятие не найдено
# 39 из 56
# === 62269 ===
# 62269 Мероприятие не найдено
# 40 из 56
# === 61677 ===
# 61677 Мероприятие не найдено
# 41 из 56
# === 56256 ===
# 56256 Мероприятие не найдено
# 42 из 56
# === 56621 ===
# 56621 Мероприятие не найдено
# 43 из 56
# === 69568 ===
# 69568 Мероприятие не найдено
# 44 из 56
# === 72834 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 45 из 56
# === 90772 ===
# 90772 Мероприятие не найдено
# 46 из 56
# === 73467 ===
# 73467 Мероприятие не найдено
# 47 из 56
# === 2 ===
# 2 Мероприятие не найдено
# 48 из 56
# === 4 ===
# 4 Мероприятие не найдено
# 49 из 56
# === 5 ===
# 5 Мероприятие не найдено
# 50 из 56
# === 62281 ===
# 62281 Мероприятие не найдено
# 51 из 56
# === 69553 ===
# 69553 Мероприятие не найдено
# 52 из 56
# === 89870 ===
# 89870 Мероприятие не найдено
# 53 из 56
# === 56716 ===
# 56716 Мероприятие не найдено
# 54 из 56
# === 63008 ===
# 63008 Мероприятие не найдено
# 55 из 56
# === 81933 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (на согласование)
# [4, 5]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 5
# 81933 Ошибка функции
# 56 из 56
# === 58543 ===
# 58543 Мероприятие не найдено
# [63209,
#  89687,
#  70792,
#  90289,
#  91617,
#  62482,
#  62932,
#  56660,
#  65802,
#  68911,
#  63088,
#  79576,
#  79021,
#  56980,
#  65806,
#  59650,
#  59649,
#  58917,
#  57108,
#  57103,
#  65801,
#  65803,
#  59323,
#  57068,
#  57091,
#  80887,
#  56744,
#  56653,
#  62709,
#  57669,
#  59942,
#  85654,
#  61475,
#  56420,
#  66695,
#  85303,
#  61471,
#  62269,
#  61677,
#  56256,
#  56621,
#  69568,
#  90772,
#  73467,
#  2,
#  4,
#  5,
#  62281,
#  69553,
#  89870,
#  56716,
#  63008,
#  81933,
#  58543]

# %%
df = (df[df['Реестр №'] < 0])
df.to_excel(file_name, index=False)
