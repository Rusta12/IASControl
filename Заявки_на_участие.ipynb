# %%
import pandas as pd
import numpy as np
import os
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
file_name = r"C:/DataIAS/Список спортмероприятий (участие).xlsx"
xls = pd.ExcelFile(file_name)
df = pd.read_excel(xls, 'Sheet1')

# %% [markdown]
# ias.search_party(df_list)

# %%
import new_ias_main_function as ias
ias.paty_approve(2025, df)
# Out:
# 0 из 60
# === 91129 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1 из 60
# === 92173 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 2 из 60
# === 66423 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 3 из 60
# === 91100 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 4 из 60
# === 92171 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 5 из 60
# === 92169 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 6 из 60
# === 92170 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 7 из 60
# === 91015 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 8 из 60
# === 63209 ===
# 10
# 0 (утверждена)
# 1 (проект)
# 2 (утверждена)
# 3 (на согласование)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 9 из 60
# === 61506 ===
# 8
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (на согласование)
# 7 (утверждена)
# [6]  Это список согла!
# 6
# Элемент найден!
# Участие соглосованно
# 10 из 60
# === 92174 ===
# 92174 Мероприятие не найдено
# 11 из 60
# === 91009 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 12 из 60
# === 91675 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 13 из 60
# === 92175 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 14 из 60
# === 91618 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 15 из 60
# === 58036 ===
# 9
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (на согласование)
# 8 (утверждена)
# [7]  Это список согла!
# 7
# Элемент найден!
# Участие соглосованно
# 16 из 60
# === 91097 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 17 из 60
# === 59164 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 18 из 60
# === 91670 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 19 из 60
# === 91626 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 20 из 60
# === 76883 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 21 из 60
# === 72421 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 22 из 60
# === 62896 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 23 из 60
# === 61567 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 24 из 60
# === 88259 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 25 из 60
# === 91896 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 26 из 60
# === 62818 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 27 из 60
# === 57999 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (на согласование)
# [6]  Это список согла!
# 6
# Элемент найден!
# Участие соглосованно
# 28 из 60
# === 89697 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# 4 (утверждена)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 29 из 60
# === 59163 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 30 из 60
# === 91894 ===
# 91894 Мероприятие не найдено
# 31 из 60
# === 91893 ===
# 91893 Мероприятие не найдено
# 32 из 60
# === 91891 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 33 из 60
# === 62889 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 34 из 60
# === 91886 ===
# 91886 Мероприятие не найдено
# 35 из 60
# === 91889 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 36 из 60
# === 61562 ===
# 2
# 0 (проект)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 37 из 60
# === 81109 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 38 из 60
# === 89553 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 39 из 60
# === 91884 ===
# 91884 Мероприятие не найдено
# 40 из 60
# === 89551 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# 6 (утверждена)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 41 из 60
# === 91871 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 42 из 60
# === 80522 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 43 из 60
# === 90989 ===
# 4
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# [0, 3]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 3
# Элемент найден!
# Участие соглосованно
# 44 из 60
# === 88384 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 45 из 60
# === 70310 ===
# 70310 Мероприятие не найдено
# 46 из 60
# === 69133 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 47 из 60
# === 81505 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 48 из 60
# === 58146 ===
# 3
# 0 (проект)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 49 из 60
# === 69892 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 50 из 60
# === 69967 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 51 из 60
# === 80544 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 52 из 60
# === 70452 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 53 из 60
# === 91731 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 54 из 60
# === 81528 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 55 из 60
# === 84536 ===
# 84536 Мероприятие не найдено
# 56 из 60
# === 58129 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 57 из 60
# === 87365 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 58 из 60
# === 91870 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 59 из 60
# === 92001 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 60 из 60
# === 68749 ===
# 68749 Мероприятие не найдено
# [92174, 91894, 91893, 91886, 91884, 70310, 84536, 68749]

# %%
df = (df[df['Реестр №'] < 0])
df.to_excel(file_name, index=False)
