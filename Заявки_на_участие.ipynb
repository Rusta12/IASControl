# %%
import pandas as pd
import numpy as np
import os
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
file_name = r"C:/DataIAS/Список спортмероприятий (участие).xlsx"
xls = pd.ExcelFile(file_name)
df = pd.read_excel(xls, 'Sheet1')

# %% [markdown]
# ias.search_party(df_list)

# %%
import new_ias_main_function as ias
ias.paty_approve(2025, df)
# Out:
# 0 из 56
# === 81437 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 1 из 56
# === 91129 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 2 из 56
# === 90802 ===
# 3
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 3 из 56
# === 91010 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 4 из 56
# === 81017 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (утверждена)
# [4]  Это список согла!
# 4
# 81017 Ошибка функции
# 5 из 56
# === 90170 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 6 из 56
# === 81838 ===
# 4
# 0 (утверждена)
# 1 (на согласование)
# 2 (утверждена)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 7 из 56
# === 91045 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 8 из 56
# === 91014 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 9 из 56
# === 81021 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (на согласование)
# 6 (утверждена)
# [5]  Это список согла!
# 5
# Элемент найден!
# Участие соглосованно
# 10 из 56
# === 91015 ===
# 91015 Мероприятие не найдено
# 11 из 56
# === 63209 ===
# 10
# 0 (утверждена)
# 1 (проект)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# []  Это список согла!
# 12 из 56
# === 90800 ===
# 3
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 13 из 56
# === 81429 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 14 из 56
# === 90799 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 15 из 56
# === 81102 ===
# 5
# 0 (утверждена)
# 1 (на согласование)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 16 из 56
# === 62679 ===
# 7
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (на согласование)
# [6]  Это список согла!
# 6
# Элемент найден!
# Участие соглосованно
# 17 из 56
# === 89671 ===
# 5
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 18 из 56
# === 81428 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 19 из 56
# === 91665 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 20 из 56
# === 62818 ===
# 6
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 21 из 56
# === 91516 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 22 из 56
# === 90034 ===
# 4
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# [3]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 23 из 56
# === 90032 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 24 из 56
# === 90031 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 25 из 56
# === 90989 ===
# 4
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 26 из 56
# === 88320 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 27 из 56
# === 91690 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 28 из 56
# === 57290 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 29 из 56
# === 68906 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 30 из 56
# === 91658 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 31 из 56
# === 57034 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (утверждена)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 32 из 56
# === 59597 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 33 из 56
# === 68401 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 34 из 56
# === 65803 ===
# 10
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (утверждена)
# 5 (утверждена)
# 6 (утверждена)
# 7 (утверждена)
# 8 (утверждена)
# 9 (на согласование)
# [9]  Это список согла!
# 9
# Элемент найден!
# Участие соглосованно
# 35 из 56
# === 86598 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 36 из 56
# === 86315 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 37 из 56
# === 64451 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 38 из 56
# === 86472 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 39 из 56
# === 57032 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# 5 (утверждена)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 40 из 56
# === 57925 ===
# 3
# 0 (утверждена)
# 1 (утверждена)
# 2 (на согласование)
# [2]  Это список согла!
# 2
# Элемент найден!
# Участие соглосованно
# 41 из 56
# === 78110 ===
# 2
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 42 из 56
# === 56914 ===
# 5
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# 4 (на согласование)
# [4]  Это список согла!
# 4
# Элемент найден!
# Участие соглосованно
# 43 из 56
# === 86307 ===
# 2
# 0 (утверждена)
# 1 (на согласование)
# [1]  Это список согла!
# 1
# Элемент найден!
# Участие соглосованно
# 44 из 56
# === 90785 ===
# 2
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 45 из 56
# === 91549 ===
# 2
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 46 из 56
# === 91869 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 47 из 56
# === 91908 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 48 из 56
# === 91051 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 49 из 56
# === 58668 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 50 из 56
# === 90889 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 51 из 56
# === 91031 ===
# 2
# 0 (на согласование)
# 1 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 52 из 56
# === 92165 ===
# 1
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 53 из 56
# === 61677 ===
# 61677 Мероприятие не найдено
# 54 из 56
# === 55365 ===
# 4
# 0 (на согласование)
# 1 (утверждена)
# 2 (утверждена)
# 3 (утверждена)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 55 из 56
# === 91602 ===
# 2
# 0 (на согласование)
# [0]  Это список согла!
# 0
# Элемент найден!
# Участие соглосованно
# 56 из 56
# === 62281 ===
# 6
# 0 (утверждена)
# 1 (утверждена)
# 2 (утверждена)
# 3 (на согласование)
# 4 (утверждена)
# 5 (на согласование)
# [3, 5]  Это список согла!
# 3
# Элемент найден!
# Участие соглосованно
# 5
# 62281 Ошибка функции
# [81017, 91015, 61677, 62281]

# %%
df = (df[df['Реестр №'] < 0])
df.to_excel(file_name, index=False)
